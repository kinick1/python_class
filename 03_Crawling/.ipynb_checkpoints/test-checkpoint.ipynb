# %%
import requests as req
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
# 멜론 차트top100 가져오기
h={'User-Agent':
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'}
a=req.get('https://www.melon.com/chart/',headers=h)
a
# Out:
# <Response [200]>

# %%
b=bs(a.text,'lxml')
b
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;TOP100&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
# <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
# <meta content="357952407588971" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/" property="og:url"/>
# <meta content="website" property="og:type"/>
# ...

# %% [markdown]
# ### 데이터 수집
# - 노래 제목
# - 가수

# %%
b.select('div.ellipsis.rank01')
# Out:
# [<div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',37138469);" title="나는 아픈 건 딱 질색이니까 재생">나는 아픈 건 딱 질색이니까</a>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',37194943);" title="밤양갱 재생">밤양갱</a>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',37140709);" title="첫 만남은 계획대로 되지 않아 재생">첫 만남은 계획대로 되지 않아</a>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',37225604);" title="EASY 재생">EASY</a>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',37145732);" title="Love wins all 재생">Love wins all</a>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',37023625);" title="비의 랩소디 재생">비의 랩소디</a>
#  </span></div>,
# ...

# %%
len(b.select('div.ellipsis.rank01'))
# Out:
# 100

# %%
b.select('div.wrap_song_info')[85]
# Out:
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11427101');" title="ASTERUM : 134-1 - 페이지 이동">ASTERUM : 134-1</a>
# </div>
# </div>

# %%
len(b.select('div.ellipsis.rank02'))
# Out:
# 100

# %%
lst1=[]
lst2=[]
for i in range(len(b.select('div.ellipsis.rank01'))):
    lst1.append(b.select('div.ellipsis.rank01')[i].text.strip())
    lst2.append(b.select('span.checkEllipsis')[i].text.strip())
lst1,lst2
# Out:
# (['나는 아픈 건 딱 질색이니까',
#   '밤양갱',
#   '첫 만남은 계획대로 되지 않아',
#   'EASY',
#   'Love wins all',
#   '비의 랩소디',
#   'To. X',
#   '홀씨',
#   '그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))',
#   '천상연',
#   'Love 119',
#   'Perfect Night',
#   'Smart',
#   '사랑은 늘 도망가',
#   '에피소드',
#   '헤어지자 말해요',
#   'Drama',
#   '인사',
#   '모래 알갱이',
#   '우리들의 블루스',
#   'Seven (feat. Latto) - Clean Ver.',
#   'WAY 4 LUV',
#   '꿈',
#   '예뻤어',
#   'Shopper',
#   'Do or Die',
#   '한 페이지가 될 수 있게',
#   '다시 만날 수 있을까',
#   'Super Lady',
#   'MANIAC',
#   'I AM',
#   '이제 나만 믿어요',
#   '무지개',
#   'Love Lee',
#   '너의 모든 순간',
#   'Wife',
#   '사랑인가 봐',
#   'London Boy',
#   'Polaroid',
#   '아버지',
#   '인생찬가',
#   'Get A Guitar',
#   'Watch Me Woo!',
#   '우리 영화',
#   '사막에서 꽃을 피우듯',
#   'From',
#   'Welcome to the Show',
#   'Hype Boy',
#   'A bientot',
#   'Baddie',
#   '버추얼 아이돌',
#   '봄날',
#   '잘 지내자, 우리 (여름날 우리 X 로이킴)',
#   'Super Shy',
#   '연애편지',
#   'You & Me',
#   '퀸카 (Queencard)',
#   '사랑할 수밖에',
# ...

# %%
df=pd.DataFrame({'노래 제목':lst1,'가수':lst2})
df
# Out:
#                               노래 제목                  가수
# 0                   나는 아픈 건 딱 질색이니까             (여자)아이들
# 1                               밤양갱           비비 (BIBI)
# 2                  첫 만남은 계획대로 되지 않아           TWS (투어스)
# 3                              EASY  LE SSERAFIM (르세라핌)
# 4                     Love wins all                 아이유
# ..                              ...                 ...
# 95                          Discord                QWER
# 96                            음악의 신     세븐틴 (SEVENTEEN)
# 97  UNFORGIVEN (feat. Nile Rodgers)  LE SSERAFIM (르세라핌)
# 98                              첫 눈                 EXO
# 99                            HAPPY         DAY6 (데이식스)
#
# [100 rows x 2 columns]

# %%
# !pip install selenium

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By


driver=wb.Chrome()
driver.get('https://www.naver.com/')

driver.find_element(By.ID,'query')
search=driver.find_element(By.ID,'query')

search.send_keys('바나나')

# %%
btn=driver.find_element(By.ID,'search-btn')
btn.click()

# %%
driver.quit()

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
import time as tm
import pandas as pd

# %%
driver=wb.Chrome()
driver.get('https://www.hsd.co.kr/menu/menu_list')

# %%
while 1:
    try:
        btn=driver.find_element(By.CLASS_NAME,'c_05')
        btn.click()
        tm.sleep(1)
    except:
        break

# %%
soup=bs(driver.page_source,'lxml')
soup
# Out:
# <html lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <!-- SNS LINK -->
# <meta content="website" property="og:type"/>
# <meta content="" property="og:title"/>
# <meta content="" property="og:url"/>
# <meta content="" property="og:image"/>
# <meta content="" property="og:description"/>
# <!--// SNS LINK -->
# <meta content="_csrf" name="_csrf_parameter"/><meta content="X-CSRF-TOKEN" name="_csrf_header"/><meta content="dc620dcd-73d6-444a-92a0-552c2c9f19b5" name="_csrf"/><title>전체메뉴 &gt; 한솥 메뉴</title>
# <link href="/assets/images/common/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/assets/css/ui.common.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/swiper.min.css" rel="stylesheet" type="text/css"/>
# ...

# %%
menus=soup.select("h4.h.fz_03")
menus[0].text
# Out:
# '이남장 설렁탕'

# %%
len(menus)
# Out:
# 97

# %%
price=soup.select('div.item-text>div>strong')
price[0].text
# Out:
# '7,900'

# %%
lst1=[]
lst2=[]

for i in range(len(menus)):
    lst1.append(menus[i].text)
    lst2.append(price[i].text)
lst1,lst2
# Out:
# (['이남장 설렁탕',
#   '제육돈까스 도련님',
#   '김피탕',
#   '사골 조랭이떡 만둣국',
#   '한우 함박스테이크 & 반달 돈까스',
#   '한우함박스테이크&토네이도소세지',
#   '해바라기',
#   '매화',
#   '진달래',
#   '개나리',
#   '돈까스도련님 고기고기',
#   '탕수육도련님 고기고기',
#   '새치 고기고기',
#   '돈치 고기고기',
#   '카츠카츠',
#   '숯불직화구이',
#   '소불고기',
#   '메가치킨제육',
#   '칠리 찹쌀탕수육도련님',
#   '동백',
#   '치킨제육',
#   '돈까스도련님',
#   '제육볶음',
#   '돈치스팸',
#   '송정식 떡갈비',
#   '제육 김치찌개 정식',
#   '제육 김치 부대찌개 정식',
#   '돈치스팸 김치 부대찌개 정식',
#   '빅치킨마요 김치 부대찌개 정식',
#   '치킨마요 김치 부대찌개 정식',
#   '빅치킨마요 김치찌개 정식',
#   '치킨마요 김치찌개 정식',
#   '빅새치마요',
#   '새치마요',
#   '메가스팸마요',
#   '스팸마요',
#   '메가치킨마요',
#   '왕치킨마요',
#   '빅치킨마요',
#   '치킨마요',
#   '참치마요',
#   '돈치마요',
#   '돈까스 카레',
#   '잡채볶음밥(중화풍 매운맛)',
#   '잡채볶음밥(오리지널)',
#   '스팸 김치볶음밥',
#   '김치볶음밥',
#   '스팸 철판볶음밥',
#   '소불고기 철판볶음밥',
#   '나시고랭',
#   '묵은지 김치찌개',
#   '김치 부대찌개',
#   '핫 치즈 닭갈비덮밥',
#   '오리지널 치즈 닭갈비덮밥',
#   '숯불직화구이 덮밥',
#   '마파두부 덮밥',
#   '왕카레돈까스덮밥',
#   '새우돈까스 덮밥',
#   '돈까스 덮밥',
#   '아보카도 소불고기 명란 비빔밥',
#   '소불고기 감초고추장 비빔밥',
#   '시골제육 두부강된장 비빔밥',
# ...

# %%
df=pd.DataFrame({"메뉴":lst1,"가격":lst2})
df
# Out:
#                     메뉴     가격
# 0              이남장 설렁탕  7,900
# 1            제육돈까스 도련님  4,900
# 2                  김피탕  5,500
# 3          사골 조랭이떡 만둣국  5,900
# 4   한우 함박스테이크 & 반달 돈까스  8,900
# ..                 ...    ...
# 92                  김치    400
# 93             무말랭이 무침    500
# 94                 한솥밥  1,000
# 95                 현미밥  1,700
# 96            리얼꿀 미니호떡  2,200
#
# [97 rows x 2 columns]

# %%
driver.quit()

# %%
# !pip install webdriver-manager
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup as bs

import time

import pandas as pd

# %%
driver=wb.Chrome()
driver.get('https://www.gmarket.co.kr/n/best')

# %%
while 1:
    # body 요소 가져와서 스크롤 하강!
    body=driver.find_element(By.TAG_NAME,"body")
    body.send_keys(Keys.END)
    
    tm.sleep(0.5)
    
    # 내리고 난 다음의 길이
    new_height=driver.execute_script("return document.body.scrollHeight")
    
    if old_height==new_height : #길이가 같은경우 멈추기
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[132], line 11
#       8 # 내리고 난 다음의 길이
#       9 new_height=driver.execute_script("return document.body.scrollHeight")
# ---> 11 if old_height==new_height : #길이가 같은경우 멈추기
#      12     break
#
# NameError: name 'old_height' is not defined

# %%
for i in range(len())

img=driver.find_elements(By.CLASS_NAME,'image__lazy.image__load')
img[0].click()

c=driver.find_element(By.CSS_SELECTOR,'body > div.location-navi > ul > li.on > a').text
t=driver.find_element(By.CSS_SELECTOR,'#itemcase_basic > div.box__item-title > h1').text
p=driver.find_element(By.CSS_SELECTOR,'#itemcase_basic > div.box__item-title > div.price > span:nth-child(2) > strong').text
c,t,p

driver.back()

# %%
len(img)
# Out:
# 20
